# %% [markdown]
# ## Week 2
#
# Please print your name and your NIM.

# %%
# here
# RIchard alberto - 0706022210024

# %% [markdown]
# ## Pandas

# %% [markdown]
# Please import the necessary library here.

# %%
# Import Library
import pandas as pd

# %% [markdown]
# <h1> Import Data

# %% [markdown]
# Please download the data from zip Elearn. <br>
# then put it on your own github account:
# 1. CSV File (Ice Cream)
# 2. Excel File (Maven Business School)
# 3. JSON File (Drake)
# 4. Text File, add header 'English' and 'France' (eng-fra)
# 5. Web Dataset - https://raw.githubusercontent.com/michellechandraa/TutorDataMining/refs/heads/main/menu.csv
#
# convert the datasets into dataframe using github url.

# %%
# 1
df = pd.read_csv('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/Ice%20Cream%20Sales%20and%20Temperature.csv')
df.head()
# Out:
#          Date   Time  Temperature (Celsius)  Ice Cream Sales
# 0  2023-01-01  08:00                     18               20
# 1  2023-01-01  08:05                     19               22
# 2  2023-01-01  08:10                     20               25
# 3  2023-01-01  08:15                     21               24
# 4  2023-01-01  08:20                     22               26

# %%
# 2
df = pd.read_excel('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/Maven%20Business%20School.xlsx')
df.head()
# Out:
#    Student ID  Undergrad Degree  Undergrad Grade  MBA Grade Work Experience  \
# 0           1          Business             68.4       90.2              No
# 1           2          Business             62.1       92.8              No
# 2           3  Computer Science             70.2       68.7             Yes
# 3           4       Engineering             75.1       80.7              No
# 4           5           Finance             60.9       74.9              No
#
#    Employability (Before)  Employability (After)      Status  Annual Salary
# 0                   252.0                  276.0      Placed       111000.0
# 1                   423.0                  410.0  Not Placed            NaN
# 2                   101.0                  119.0      Placed       107000.0
# 3                   288.0                  334.0  Not Placed            NaN
# 4                   248.0                  252.0  Not Placed            NaN

# %%
# 3
df = pd.read_json('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/drake_data.json')
df.head()
# Out:
#                  album                           lyrics_title  \
# 0  Certified Lover Boy            Certified Lover Boy* Lyrics
# 1  Certified Lover Boy  Like I’m Supposed To/Do Things Lyrics
# 2  Certified Lover Boy                      Not Around Lyrics
# 3  Certified Lover Boy    In the Cut (Ft. Roddy Ricch) Lyrics
# 4  Certified Lover Boy  Zodiac Sign (Ft. Jessie Reyez) Lyrics
#
#                                           lyrics_url  \
# 0  https://genius.com/Drake-certified-lover-boy-l...
# 1  https://genius.com/Drake-like-im-supposed-to-d...
# 2         https://genius.com/Drake-not-around-lyrics
# 3         https://genius.com/Drake-in-the-cut-lyrics
# 4        https://genius.com/Drake-zodiac-sign-lyrics
#
#                                               lyrics track_views
# 0  Lyrics from CLB Merch\n\n[Verse]\nPut my feeli...        8.7K
# 1  [Verse]\nHands are tied\nSomeone's in my ear f...       38.8K
# 2  [Intro]\nYeah, we back\nWassup ladies?\nSwisha...      129.8K
# ...

# %%
# 4
df = pd.read_table('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/eng-fra.txt')
df.head()
# Out:
#      Go.        Va !
# 0   Run!     Cours !
# 1   Run!    Courez !
# 2   Wow!  Ça alors !
# 3  Fire!    Au feu !
# 4  Help!  À l'aide !

# %%
# 5
df = pd.read_csv('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/menu.csv')
df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %% [markdown]
# <h1> Try Yourself

# %% [markdown]
# a. Import MLBB HERO DATASET into dataframe <br>
# b. show 10 random data from dataset <br>
# c. Find out if there are any missing values in each column <br>
# d. drop the unnecessary column <br>
# e. show the roles of the hero in that dataset <br>
# f. show the most difficult hero to use<br>
# g. find out which ones has the average higher physical_atk between Fighters and Tank<br>
# output example: <br>
# "Fighters have higher average physical attack than Tanks." <br>
# "Tanks have higher average physical attack than Fighters." <br>
# "Fighters and Tanks have the same average physical attack." <br>
# h. Make a visualization showing percentages of heroes based on their role

# %%
# a
df = pd.read_csv('https://raw.githubusercontent.com/blaqqqqq/datasets/refs/heads/main/drive-download-20240926T043517Z-001/mlbb_hero.csv', delimiter = ';')

# %%
# b
df.head(10)
# Out:
#     hero_name      role  defense_overall  offense_overall  \
# 0     Terizla   fighter              7.0              8.0
# 1      Martis   fighter              6.0              8.0
# 2       Grock      tank              8.0              5.0
# 3    Carmilla   support              5.0              5.0
# 4     Irithel  marksman              5.0              5.0
# 5      Thamuz   fighter              7.0              7.0
# 6     Leomord   fighter              6.0              8.0
# 7       Lunox      mage              7.0              5.0
# 8      Aurora      mage              4.0              5.0
# 9  Minsitthar   fighter              6.0              7.0
#
#    skill_effect_overall  difficulty_overall  movement_spd  magic_defense  \
# 0                   6.0                 6.0           255             10
# 1                   5.0                 5.0           260             10
# 2                   6.0                 4.0           260             10
# ...

# %%
# c
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# hero_name                 0
# role                      0
# defense_overall           0
# offense_overall           0
# skill_effect_overall      0
# difficulty_overall        0
# movement_spd              0
# magic_defense             0
# mana                      0
# hp_regen                  0
# physical_atk              0
# physical_defense          0
# hp                        0
# attack_speed              0
# mana_regen                0
# win_rate                  0
# pick_rate                 0
# ban_rate                  0
# release_year              0
# Unnamed: 19             103
# dtype: int64

# %%
# d
df_cleaned = df.drop(columns=['release_year', 'win_rate', 'pick_rate', 'ban_rate'])

# %%
# e
roles = df_cleaned['role'].unique()
print(roles)
# Out:
# ['fighter' 'tank' 'support' 'marksman' 'mage' 'assassin']

# %%
# f
most_difficult_hero = df_cleaned.loc[df_cleaned['difficulty_overall'].idxmax()]
print(most_difficult_hero['hero_name'])
# Out:
# Fanny

# %%
# g
fighter_avg_atk = df_cleaned[df_cleaned['role'] == 'Fighter']['physical_atk'].mean()
tank_avg_atk = df_cleaned[df_cleaned['role'] == 'Tank']['physical_atk'].mean()

if fighter_avg_atk > tank_avg_atk:
    print("Fighters have higher average physical attack than Tanks.")
elif tank_avg_atk > fighter_avg_atk:
    print("Tanks have higher average physical attack than Fighters.")
else:
    print("Fighters and Tanks have the same average physical attack.")
# Out:
# Fighters and Tanks have the same average physical attack.

# %%
# himport matplotlib.pyplot as plt

role_counts = df_cleaned['role'].value_counts()
role_percentages = role_counts / role_counts.sum() * 100

# Plot
plt.figure(figsize=(8, 8))
plt.pie(role_percentages, labels=role_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Hero Role Percentages')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# 7. I have a character with this specification:
# defense_overall 6.0<br>
# offense_overall 7.0<br>
# skill_effect_overall 4.0<br>
# difficulty_overall 3.0<br>
# movement_spd 250<br>
# magic_defense 9<br>
# mana 380<br>
# hp_regen 37<br>
# physical_atk 119<br>
# physical_defense 24<br>
# hp 2689<br>
# attack_speed 0.75<br>
# mana_regen 16.0<br>
#
# Please predict its role using DecisionTree classification algorithm <br>

# %%
# 7
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
label_encoder = LabelEncoder()

# Encode the 'role' column
df['role'] = label_encoder.fit_transform(df['role'])

# Separate features and target variable
X = df[['defense_overall',
              'offense_overall',
              'skill_effect_overall',
              'difficulty_overall',
              'movement_spd',
              'magic_defense',
              'mana',
              'hp_regen',
              'physical_atk',
              'physical_defense',
              'hp',
              'attack_speed',
              'mana_regen']]
y = df['role']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 10)

# Create a Decision Tree Classifier
dtree = DecisionTreeClassifier()

# Train the model
dtree.fit(X_train, y_train)

# Make predictions on the test set
y_pred = dtree.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: {}".format(accuracy))

# Predict the role for the given character
character_data = {
    'defense_overall': 6.0,
    'offense_overall': 7.0,
    'skill_effect_overall': 4.0,
    'difficulty_overall': 3.0,
    'movement_spd': 250,
    'magic_defense': 9,
    'mana': 380,
    'hp_regen': 37,
    'physical_atk': 119,
    'physical_defense': 24,
    'hp': 2689,
    'attack_speed': 0.75,
    'mana_regen': 16.0
}
char_data = pd.DataFrame([character_data])
predict = dtree.predict(char_data)
print("Predicted role (encoded): {}".format(predict))

# Get the predicted role (dicoding)
role_name = label_encoder.inverse_transform(predict)

print("The decoded role is:", role_name[0])
# Out:
# Accuracy: 0.8095238095238095
# Predicted role (encoded): [1]
# The decoded role is: 1

# %% [markdown]
# 8. Why is CSV one of the most commonly used file formats in the field of data science? <br>

# %%
# 8
#CSV (Comma-Separated Values) is one of the most commonly used file formats in data science due to its simplicity, versatility, and widespread compatibility. 
#It is a lightweight, plain-text format that can be easily created, read, and edited using various tools, 
#from basic text editors to advanced data analysis software like Excel, Python, or R. CSV files allow easy exchange of data between different platforms and programming environments without the need for complex libraries or tools. 
#Its structure—rows and columns, separated by commas—aligns well with tabular data, making it intuitive for handling datasets. 
#Additionally, its lack of formatting makes it highly efficient for large datasets, which is crucial for many data science applications.

#https://chatgpt.com/share/66f52595-d6a0-8004-a452-eb827ce99866
